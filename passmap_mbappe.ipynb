# %%
from statsbombpy import sb
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
import seaborn as sns

# %%
sb.competitions()
matches = sb.matches(competition_id=43, season_id=106)

# %%
events = sb.events(match_id=3869685)
events.head()
# Out:
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                NaN                  NaN                     NaN
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                            NaN              NaN             NaN
# 1                            NaN              NaN             NaN
# 2                            NaN              NaN             NaN
# 3                            NaN              NaN             NaN
# 4                            NaN              NaN             NaN
#
#   carry_end_location clearance_aerial_won clearance_body_part  ...  \
# 0                NaN                  NaN                 NaN  ...
# 1                NaN                  NaN                 NaN  ...
# 2                NaN                  NaN                 NaN  ...
# 3                NaN                  NaN                 NaN  ...
# 4                NaN                  NaN                 NaN  ...
#
#   shot_technique shot_type substitution_outcome substitution_replacement  \
# 0            NaN       NaN                  NaN                      NaN
# 1            NaN       NaN                  NaN                      NaN
# 2            NaN       NaN                  NaN                      NaN
# 3            NaN       NaN                  NaN                      NaN
# 4            NaN       NaN                  NaN                      NaN
#
#                                              tactics       team team_id  \
# 0  {'formation': 433, 'lineup': [{'player': {'id'...  Argentina     779
# 1  {'formation': 4231, 'lineup': [{'player': {'id...     France     771
# 2                                                NaN     France     771
# 3                                                NaN  Argentina     779
# 4                                                NaN     France     771
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI            NaN
# 1  00:00:00.000  Starting XI            NaN
# 2  00:00:00.000   Half Start            NaN
# 3  00:00:00.000   Half Start            NaN
# 4  00:00:00.000   Half Start            NaN
#
# [5 rows x 91 columns]

# %%
events = events[['team', 'type', 'minute', 'location', 'pass_end_location', 'player']]
events = events[events['team']=='France'].reset_index()

# %%
events = events[events['type']=='Pass']
events = events[events['player']=='Kylian Mbappé Lottin']

# %%
events
# Out:
#      index    team  type  minute       location pass_end_location  \
# 17      59  France  Pass       4   [38.8, 46.8]      [32.1, 30.5]
# 28      74  France  Pass       5    [68.7, 5.9]      [56.1, 10.2]
# 67     145  France  Pass      13   [99.1, 19.2]      [99.5, 28.2]
# 87     198  France  Pass      17    [81.8, 5.1]       [68.9, 7.7]
# 99     210  France  Pass      18   [86.7, 14.1]      [103.6, 7.9]
# 107    248  France  Pass      24    [98.0, 0.1]       [87.5, 7.7]
# 109    250  France  Pass      24   [105.9, 5.5]     [104.6, 28.4]
# 137    370  France  Pass      37   [66.8, 10.6]      [45.4, 30.3]
# 142    394  France  Pass      38   [87.1, 10.4]      [94.4, 21.3]
# 192    488  France  Pass      46    [91.8, 4.7]      [99.7, 10.9]
# 260    626  France  Pass      53   [74.1, 15.1]      [76.9, 18.1]
# 312    702  France  Pass      62    [71.3, 2.5]      [68.1, 14.3]
# 315    705  France  Pass      63   [97.6, 17.7]     [102.7, 17.5]
# 352    764  France  Pass      68   [67.0, 18.1]      [63.6, 23.0]
# 359    779  France  Pass      68   [79.0, 17.0]      [109.4, 3.4]
# 364    784  France  Pass      69   [92.9, 15.8]      [94.0, 10.8]
# 375    800  France  Pass      70    [98.9, 8.7]     [101.0, 12.3]
# 408    873  France  Pass      78    [60.2, 7.6]      [90.3, 18.1]
# 418    891  France  Pass      80   [93.1, 24.1]      [94.8, 36.3]
# 423    919  France  Pass      84  [108.3, 20.3]     [120.0, 57.3]
# 439    937  France  Pass      86   [74.7, 63.0]      [75.8, 67.7]
# 441    939  France  Pass      86   [80.3, 61.5]      [99.3, 47.4]
# 451    951  France  Pass      89   [92.3, 25.4]     [111.9, 65.6]
# 461    967  France  Pass      92   [86.7, 18.1]     [106.2, 30.7]
# 467    986  France  Pass      95    [79.4, 4.6]      [95.5, 21.5]
# 468    987  France  Pass      95  [110.9, 23.5]     [113.4, 23.9]
# 569   1245  France  Pass     119    [79.0, 4.2]     [120.0, 47.6]
#
#                    player
# 17   Kylian Mbappé Lottin
# 28   Kylian Mbappé Lottin
# 67   Kylian Mbappé Lottin
# 87   Kylian Mbappé Lottin
# 99   Kylian Mbappé Lottin
# 107  Kylian Mbappé Lottin
# 109  Kylian Mbappé Lottin
# 137  Kylian Mbappé Lottin
# 142  Kylian Mbappé Lottin
# 192  Kylian Mbappé Lottin
# 260  Kylian Mbappé Lottin
# 312  Kylian Mbappé Lottin
# 315  Kylian Mbappé Lottin
# 352  Kylian Mbappé Lottin
# 359  Kylian Mbappé Lottin
# 364  Kylian Mbappé Lottin
# 375  Kylian Mbappé Lottin
# 408  Kylian Mbappé Lottin
# 418  Kylian Mbappé Lottin
# 423  Kylian Mbappé Lottin
# 439  Kylian Mbappé Lottin
# 441  Kylian Mbappé Lottin
# 451  Kylian Mbappé Lottin
# 461  Kylian Mbappé Lottin
# 467  Kylian Mbappé Lottin
# 468  Kylian Mbappé Lottin
# 569  Kylian Mbappé Lottin

# %%
#Drawing the pitch using a template from MPL Soccer

pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')
plt.gca().invert_yaxis()

#Passes in the first half are yellow
#Passes in the second half are green
#Passes in extra time are in orange
#Circle is the start location of the Pass
for i in range(size):
    ev = events.iloc[i]
    if(ev['minute']>45 and ev['minute']<= 90):
        plt.plot((ev['location'][0], ev['pass_end_location'][0]),
             (ev['location'][1], ev['pass_end_location'][1]), 
             color='green')
        plt.scatter(ev['location'][0],ev['location'][1], color='green')
    elif(ev['minute']<45):
        plt.plot((ev['location'][0], ev['pass_end_location'][0]),
             (ev['location'][1], ev['pass_end_location'][1]), 
             color='yellow')
        plt.scatter(ev['location'][0],ev['location'][1], color='yellow')
    else:
        plt.plot((ev['location'][0], ev['pass_end_location'][0]),
             (ev['location'][1], ev['pass_end_location'][1]), 
             color='orange')
        plt.scatter(ev['location'][0],ev['location'][1], color='orange')

plt.title('Mbappe Pass Map WC2022 Final vs Argentina', color = 'black', size=20)
plt.savefig('pmap.png')
